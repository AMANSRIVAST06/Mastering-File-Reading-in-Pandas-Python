# %%
import pandas as pd

# %% [markdown]
# # Read Csv

# %%
CsvFile=pd.read_csv("C:\\Users\\LENOVO\\OneDrive\\Desktop\\excel filws\\employees_data.csv") 
CsvFile
# Out:
#     id         name   position     salary  department
# 0    1   Employee_1     Intern   47420.72  Operations
# 1    2   Employee_2     Intern   73215.62     Finance
# 2    3   Employee_3     Intern   95426.30          HR
# 3    4   Employee_4  Developer   78650.79  Operations
# 4    5   Employee_5     Intern   91590.36     Finance
# 5    6   Employee_6  Developer   40471.25  Operations
# 6    7   Employee_7    Analyst   55619.30     Finance
# 7    8   Employee_8     Intern   75941.12     Finance
# 8    9   Employee_9    Analyst   83982.63   Marketing
# 9   10  Employee_10     Intern   91467.97          HR
# 10  11  Employee_11     Intern  118460.62   Marketing
# 11  12  Employee_12     Intern   39913.92          IT
# 12  13  Employee_13     Intern   67328.21   Marketing
# 13  14  Employee_14    Analyst  104081.27          IT
# 14  15  Employee_15    Manager   68670.53          HR
# 15  16  Employee_16  Developer   35559.80          HR
# ...

# %% [markdown]
# # Read Excel file

# %%
ExcelFile=pd.read_excel("C:\\Users\\LENOVO\\OneDrive\\Desktop\\excel filws\\Bookings-20000-Rows.xlsx",sheet_name='July')
ExcelFile
# Out:
#                      Date      Time     Booking_ID        Booking_Status  \
# 0     2024-07-26 14:00:00  14:00:00  CNR7153255142    Canceled by Driver
# 1     2024-07-25 22:20:00  22:20:00  CNR2940424040               Success
# 2     2024-07-30 19:59:00  19:59:00  CNR2982357879               Success
# 3     2024-07-22 03:15:00  03:15:00  CNR2395710036  Canceled by Customer
# 4     2024-07-02 09:02:00  09:02:00  CNR1797421769               Success
# ...                   ...       ...            ...                   ...
# 20402 2024-07-27 19:46:00  19:46:00  CNR9637947510  Canceled by Customer
# 20403 2024-07-18 05:38:00  05:38:00  CNR4070839222               Success
# 20404 2024-07-25 12:38:00  12:38:00  CNR2768163393               Success
# 20405 2024-07-21 07:58:00  07:58:00  CNR7143313454               Success
# 20406 2024-07-17 02:53:00  02:53:00  CNR4049412680    Canceled by Driver
#
#       Customer_ID Vehicle_Type  Pickup_Location Drop_Location  V_TAT  C_TAT  \
# ...

# %% [markdown]
# # Read Json File

# %%
JsonFile=pd.read_json("C:\\Users\\LENOVO\\OneDrive\\Desktop\\practice\\tmline.json")
JsonFile
# Out:
#        name  age  salary
# 0    Manish   20   20000
# 1    Nikita   25   21000
# 2    Pritam   16   22000
# 3  Prantosh   35   25000
# 4    Vikash   67   40000

# %% [markdown]
# # Read Html Page

# %%
HtmlRead=pd.read_html('https://en.wikipedia.org/wiki/Minnesota')
HtmlRead
# Out:
# [                                            Minnesota  \
#  0                                               State
#  1                                            FlagSeal
#  2   Nicknames: North Star State; Gopher State; Lan...
#  3   Motto: L'Étoile du Nord (French: The Star of t...
#  4                           Anthem: "Hail! Minnesota"
#  5      Location of Minnesota within the United States
#  6                                             Country
#  7                                    Before statehood
#  8                               Admitted to the Union
#  9                                             Capital
#  10                                       Largest city
#  11                       Largest county or equivalent
#  12                      Largest metro and urban areas
#  13                                         Government
#  14                                         • Governor
#  15                              • Lieutenant Governor
# ...

# %% [markdown]
# # Read mysql Database

# %%
import mysql.connector
print("✅ MySQL Connector is working!")
# Out:
# ✅ MySQL Connector is working!

# %%
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="rootaman",
    database="tfq"
)

query="select * from details"

sql_read=pd.read_sql(query,conn)
sql_read
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_14820\1549093148.py:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_read=pd.read_sql(query,conn)
#   EMPNAME       DEPT    CONTACTNO       CITY
# 0  VISHAL      SALES   9193458625   GAZIABAD
# 1   VIPIN    MANAGER   7352158944   BAREILLY
# 2   ROHIT         IT   7830246946     KANPUR
# 3   RAHUL  MARKETING   9635688441     MEERUT
# 4  SANJAY      SALES   9149335694  MORADABAD
# 5   VIPIN    MANAGER   7352158944   BAREILLY
# 6  VISHAL      SALES   9193458625   GAZIABAD
# 7    AMAN         IT  78359941265     RAMPUR
# 8    ANSH      SALES   6554322456     MEERUT

# %%
# !pip install SQLAlchemy

# %%
from sqlalchemy import create_engine

# %%
connEngine=create_engine('mysql+mysqlconnector://root:rootaman@localhost/tfq')
sql_read1=pd.read_sql(query,connEngine)
sql_read1
# Out:
#   EMPNAME       DEPT    CONTACTNO       CITY
# 0  VISHAL      SALES   9193458625   GAZIABAD
# 1   VIPIN    MANAGER   7352158944   BAREILLY
# 2   ROHIT         IT   7830246946     KANPUR
# 3   RAHUL  MARKETING   9635688441     MEERUT
# 4  SANJAY      SALES   9149335694  MORADABAD
# 5   VIPIN    MANAGER   7352158944   BAREILLY
# 6  VISHAL      SALES   9193458625   GAZIABAD
# 7    AMAN         IT  78359941265     RAMPUR
# 8    ANSH      SALES   6554322456     MEERUT

# %% [markdown]
# # Read from MS SQL

# %%
import pyodbc
import pandas as pd

# Connection string — update with your server info
conn = pyodbc.connect(
    "DRIVER={ODBC Driver 17 for SQL Server};"
    "SERVER=LAPTOP-OKFEONN4;"  # or 'SERVER_NAME\INSTANCE'
    "DATABASE=Trigger_db;"
    "Trusted_Connection=yes;"
)

# Query
query = "SELECT * FROM sale"

# Load into DataFrame
dff1 = pd.read_sql(query, conn)

# Show result
print(dff1.head())
# Out:
#    ProductID ProductName SaleQuarter  SalesAmount
# 0          1      Laptop          Q1       1500.0
# 1          2    Keyboard          Q1         75.0
# 2          3       Mouse          Q1         30.0
# 3          1      Laptop          Q2       1600.0
# 4          2    Keyboard          Q2         80.0
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_14820\3237795681.py:16: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dff1 = pd.read_sql(query, conn)

# %% [markdown]
# # Read Parquet

# %%
filepath="C:\\Users\\LENOVO\\OneDrive\\Desktop\\practice\\userdata1.parquet"

# %%
df1 = pd.read_parquet(filepath, engine='pyarrow')
df1
# Out:
#       registration_dttm    id first_name last_name                     email  \
# 0   2016-02-03 07:55:29     1     Amanda    Jordan          ajordan0@com.com
# 1   2016-02-03 17:04:03     2     Albert   Freeman           afreeman1@is.gd
# 2   2016-02-03 01:09:31     3     Evelyn    Morgan   emorgan2@altervista.org
# 3   2016-02-03 00:36:21     4     Denise     Riley          driley3@gmpg.org
# 4   2016-02-03 05:05:31     5     Carlos     Burns  cburns4@miitbeian.gov.cn
# ..                  ...   ...        ...       ...                       ...
# 995 2016-02-03 10:30:59   996     Dennis    Harris      dharrisrn@eepurl.com
# 996 2016-02-03 17:16:53   997     Gloria  Hamilton    ghamiltonro@rambler.ru
# 997 2016-02-03 05:02:20   998      Nancy    Morris         nmorrisrp@ask.com
# 998 2016-02-03 02:41:32   999      Annie   Daniels    adanielsrq@squidoo.com
# 999 2016-02-03 09:52:18  1000      Julie     Meyer       jmeyerrr@flavors.me
#
# ...

# %% [markdown]
# #  Text Files (Custom Delimiters)

# %%
pipedeli=pd.read_csv("C:\\Users\\LENOVO\\OneDrive\\Desktop\\practice\\pipedelimited.txt",delimiter='|')
pipedeli
# Out:
#    id            name  age                        email             city
# 0   1    Brandon Rice   27      brandonrice@example.com          Newport
# 1   2   Tiffany Lopez   42  tiffany.lopez88@example.org    Port Ericstad
# 2   3    James Rivera   33     james.rivera@example.com   Lake Ericaberg
# 3   4  Angela Griffin   55   angela.griffin@example.net  Mckenziechester
# 4   5   Jonathan Hall   24    jonathan.hall@example.com       South Mark

# %% [markdown]
# # Read clipboard

# %%
cp=pd.read_clipboard()
cp
# Out:
#    id            name  age                        email             city
# 0   1    Brandon Rice   27      brandonrice@example.com          Newport
# 1   2   Tiffany Lopez   42  tiffany.lopez88@example.org    Port Ericstad
# 2   3    James Rivera   33     james.rivera@example.com   Lake Ericaberg
# 3   4  Angela Griffin   55   angela.griffin@example.net  Mckenziechester
# 4   5   Jonathan Hall   24    jonathan.hall@example.com       South Mark
